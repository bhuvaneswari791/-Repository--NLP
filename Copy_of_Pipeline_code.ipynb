# %%
text = "Artificial intelligence is changing the world. Google is located in USA."

from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(text)
print("Segmentation:", sentences)
# Out:
# Segmentation: ['Artificial intelligence is changing the world.', 'Google is located in USA.']

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
named_entities = nltk.ne_chunk(pos_tags)
print("Named Entities:", named_entities)
# Out:
# Named Entities: (S
#   (GPE Artificial/JJ)
#   intelligence/NN
#   is/VBZ
#   changing/VBG
#   the/DT
#   world/NN
#   ./.
#   (PERSON Google/NNP)
#   is/VBZ
#   located/VBN
#   in/IN
#   (ORGANIZATION USA/NNP)
#   ./.)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print("Tokenization:", tokens)
# Out:
# Tokenization: ['Artificial', 'intelligence', 'is', 'changing', 'the', 'world', '.', 'Google', 'is', 'located', 'in', 'USA', '.']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed = [ps.stem(w) for w in tokens]
print("Stemming:", stemmed)
# Out:
# Stemming: ['artifici', 'intellig', 'is', 'chang', 'the', 'world', '.', 'googl', 'is', 'locat', 'in', 'usa', '.']

# %%
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
lemmatized = [lemm.lemmatize(w) for w in tokens]
print("Lemmatization:", lemmatized)
# Out:
# Lemmatization: ['Artificial', 'intelligence', 'is', 'changing', 'the', 'world', '.', 'Google', 'is', 'located', 'in', 'USA', '.']

# %%
pos_tags = nltk.pos_tag(tokens)
print("POS Tagging:", pos_tags)
# Out:
# POS Tagging: [('Artificial', 'JJ'), ('intelligence', 'NN'), ('is', 'VBZ'), ('changing', 'VBG'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Google', 'NNP'), ('is', 'VBZ'), ('located', 'VBN'), ('in', 'IN'), ('USA', 'NNP'), ('.', '.')]

# %%
import nltk
nltk.download('words') # Ensure words are downloaded right before use
named_entities = nltk.ne_chunk(pos_tags)
print("Named Entities:", named_entities)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Named Entities: (S
#   (GPE Artificial/JJ)
#   intelligence/NN
#   is/VBZ
#   changing/VBG
#   the/DT
#   world/NN
#   ./.
#   (PERSON Google/NNP)
#   is/VBZ
#   located/VBN
#   in/IN
#   (ORGANIZATION USA/NNP)
#   ./.)

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %% [markdown]
# # Task
# `nltk.download('punkt_tab')`
# `nltk.download('words')`
# `nltk.download('wordnet')`
# `nltk.download('averaged_perceptron_tagger_eng')`
# `nltk.download('maxent_ne_chunker_tab')`

# %% [markdown]
# ## Download NLTK Resources
#
# ### Subtask:
# Download all necessary NLTK data, including 'punkt_tab', 'words', 'wordnet', 'averaged_perceptron_tagger_eng', and 'maxent_ne_chunker_tab', to ensure all subsequent NLP tasks can run without errors.

# %% [markdown]
# **Reasoning**:
# The subtask requires downloading the 'punkt_tab' resource. The notebook already contains a code cell to perform this action, so I will instruct the execution of that cell.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# **Reasoning**:
# The subtask requires downloading the 'words' resource. The notebook already contains a code cell (libE-xygVNia) to perform this action, so I will instruct the execution of that cell.

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# **Reasoning**:
# The subtask requires downloading the 'wordnet' resource. The notebook already contains a code cell (-kGievooVVrQ) to perform this action, so I will instruct the execution of that cell.

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# **Reasoning**:
# The subtask requires downloading the 'averaged_perceptron_tagger_eng' resource. The notebook already contains a code cell (lZLIWP4RVavj) to perform this action, so I will instruct the execution of that cell.

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# **Reasoning**:
# The subtask requires downloading the 'maxent_ne_chunker_tab' resource. The notebook already contains a code cell (cmAILLWMV0Gd) to perform this action, so I will instruct the execution of that cell.

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %% [markdown]
# **Reasoning**:
# The `maxent_ne_chunker_tab` resource has now been successfully downloaded. The next step is to execute the cell that performs named entity recognition using `nltk.ne_chunk`, which previously failed due to the missing resource.

# %%
named_entities = nltk.ne_chunk(pos_tags)
print("Named Entities:", named_entities)
# Out:
# Named Entities: (S
#   (GPE Artificial/JJ)
#   intelligence/NN
#   is/VBZ
#   changing/VBG
#   the/DT
#   world/NN
#   ./.
#   (PERSON Google/NNP)
#   is/VBZ
#   located/VBN
#   in/IN
#   (ORGANIZATION USA/NNP)
#   ./.)
